# %% [markdown]
# # GRIP - JUNE23 - The Sparks Foundation

# %% [markdown]
# # Task 3 : Exploratory Data Analysis - Retail

# %% [markdown]
# Problem statement : Perform 'Exploratory Data Analysis' on dataset 'SampleSuperstore' This task is about Exploratory Data Analysis - Retail where the task focuses on a business manager who will try to find out weak areas where he can work to make more profit.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
Data = pd.read_csv('SampleSuperstore.csv')

# %%
Data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
Data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
Data.info
# Out:
# <bound method DataFrame.info of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
Data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
Data.duplicated().sum()
# Out:
# 17

# %%
Data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
Data['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
sns.barplot(x = 'Category', y = 'Profit', data=Data)
plt.title('Profit by Category')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.barplot(x ='Sub-Category', y='Profit', data=Data)
plt.title('Profit by Sub-Category')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x ='Region', y='Sales', data = Data, estimator = sum)
plt.title('Sales by Region')
plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x = 'Region', y='Profit', data = Data, estimator = sum)
plt.title('Profit by Region')
plt.show()

# %%
corr_matrix = Data.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.barplot(x='Ship Mode',y='Profit',data=Data)
plt.title("Profit Margin by Shipping Mode")
plt.show()

# %%
sns.scatterplot(x='Sales',y='Profit',hue='Region',data=Data)
plt.title("Sales and Profit by Region")
plt.show()

# %%
plt.figure(figsize=(15,12))
Data['Sub-Category'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
Data['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=Data,palette='rocket_r',order=Data['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
Data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
plt.figure(figsize=(10,8))
Data['Region'].value_counts().plot.pie(autopct = '%1.1f%%')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,8))
ax.scatter(df['Sales'],Data['Profit'])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %%
sns.lineplot(x='Discount',y='Profit',label='Profit',data=Data)
plt.legend()
plt.show()

# %%
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=Data)
plt.legend()
plt.show()

# %%
Data.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['pink','blue'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each Region')
sns.barplot(x='Region',y='Sales',data=Data,hue='Segment',order=Data['Region'].value_counts().index,palette='rocket')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
Data.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %%
ps = Data.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['blue','orange'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %%
t_states = Data['State'].value_counts().nlargest(10)
t_states
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
Data.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['yellow','purple'],alpha=0.9,figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %%
ps = Data.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['red','lightblue'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# # Observations:

# %% [markdown]
# 1.Maximum are from Binders, Paper, furnishings, Phones, storage, art, accessories and minimum from copiers, machines, suppliers

# %% [markdown]
# 2.Highest number of buyers are from California and New York

# %% [markdown]
# 3.Most customers tends to buy quantity of 2 and 3 Discount give maximum is 0 to 20 percent

# %% [markdown]
# 4.No correlation between profit and discount

# %% [markdown]
# 5.Profit ans sales are maximum in consumer segment and minimun in Home Office segment

# %% [markdown]
# 6.Segment wise sales are almost same in every region

# %% [markdown]
# 7.Profit and sales are maximum in west region and minimum in south region

# %% [markdown]
# 8.High profit is for California, New York

# %% [markdown]
# 9.Loss is for Texas, Pennsylvania, Ohio

# %% [markdown]
# 10.As a business manager, try to find out the weak areas where you can work to make more profit?
#  *Technology and Office Supplies have high profit.
#  *Furniture have less profit

# %% [markdown]
# 11.hones sub-category have high sales.

# %% [markdown]
# 12.Chairs have high sales but less profit compared to phones

# %% [markdown]
# 13.Tables and Bookmarks sub-categories facing huge loss

# %% [markdown]
# # Thank you
